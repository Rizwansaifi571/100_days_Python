# %% [markdown]
# # Treaure_Hunt Game.
# Date : 27, Jan, 2024.

# %%
print("Find The Treasure !")   

print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')

print("\n....start the game.. type 'start'")
start = input()

if start.lower() == "start":
    print("Welcome to Treasure Island.")
    print("Your mission is to find the treasure hidden in a mountain cave....") 
    name = input("Enter your name: ")
    print(f"\n{name}, your adventure begins when you discover a map on your way to school.")
    print("The map reveals a red mark near the mountain lake.")
    print("\nYou embark on a journey filled with challenges and riddles. Let the quest for treasure begin!\n")

    print("As you enter the cave, a wise owl appears before you.")
    print(f"Wise Owl: Hey, {name}! Where are you headed?")
    print(f"{name}: I seek the hidden treasure inside the cave.")
    print("Wise Owl: Alright, but first, you must answer my question. A wrong answer could be fatal!\n")

    answer = input('Wise Owl: "I speak without a mouth and hear without ears. I have no body, but I come alive with the wind. What am I?"\nYour answer: ')

    if answer.lower() == "echo":
        print('Wise Owl: Bravo! You may proceed on your quest.\n')

        print("Continuing your journey, you encounter a mysterious old man with another riddle:")
        print('Old Man: "The more you take, the more you leave behind. What am I?"')

        answer2 = input("Your answer: ")
        if answer2.lower() == "footsteps":
            print('Old Man: Impressive! You can now move forward.\n')

            print("As you venture deeper, you find a locked door with a riddle:")
            print('Riddle: "I fly without wings. I cry without eyes. Wherever I go, darkness follows me. What am I?"')

            answer3 = input("Your answer: ")
            if answer3.lower() == "cloud":
                print("The door opens, revealing a talking parrot.")
                print('Parrot: "You\'re doing well, adventurer! Here\'s your next challenge:')
                print('I have keys but no locks. I have space but no room. You can enter, but you can\'t go inside. What am I?"')

                answer4 = input("Your answer: ")
                if answer4.lower() == "keyboard":
                    print('Parrot: Clever! Move ahead and face the next trial.\n')

                    print("Venturing deeper, you encounter a shadowy figure with another riddle:")
                    print('Figure: "The more you look at it, the less you see. What is it?"')

                    answer5 = input("Your answer: ")
                    if answer5.lower() == "darkness":
                        print('Figure: Well done! You\'re on the right path. The treasure awaits you.\n')
                        print("Congratulations, adventurer! You have successfully navigated through the challenges and found the hidden treasure.")
                    else:
                        print("\nOops! Your journey ends here. Game over!")

                else:
                    print("\nOops! Your journey ends here. Game over!")

            else:
                print("\nOops! Your journey ends here. Game over!")

        else:
            print("\nOops! Your journey ends here. Game over!")

    else:
        print('\nWise Owl: OOPS! You are wrong! Prepare to face the consequences. GAME OVER!\n')

# %% [markdown]
# Another Game.

# %%
import random

print("\n.... embark on the quest for treasure......\n")

print('''
*******************************************************************************
               /\                           
              /  \    ____
             /    \  |  o | 
            /      \| ___ |    
           /  /\  \    |____
          /  /  \  \  | |
         /  /    \  \ || |   
        /  /      \  \|| |  
       /  /        \  \ | | 
      /  /          \__\|_|___
     /  /             |__|_____)
    /  /
   /  /
  /  /
 /  /
/  /                                                                      
*******************************************************************************
''')

print("\n Start the game.. type 'start'")
start = input()

if start.lower() == "start":
    print("Welcome to the Enchanted Forest Adventure!")
    print("Your mission is to find the legendary Crystal of Destiny hidden in the heart of the enchanted forest.") 
    name = input("Enter your name: ")
    print(f"\n{name}, you are a brave explorer who stumbles upon a magical portal while wandering through the woods.")
    print("The portal transports you to a mystical world filled with challenges and wonders. Your quest begins now!\n")

    print("You find yourself in front of an ancient gate guarded by a mystical creature.")
    print(f"Mystical Creature: Greetings, {name}! To pass through, answer my riddle:")
    print('Mystical Creature: "I have cities but no houses. I have mountains but no trees. I have water but no fish. What am I?"\n')

    answer = input("Your answer: ")

    if answer.lower() == "map":
        print('Mystical Creature: Well done! You may proceed to the Enchanted Garden.\n')

        print("In the Enchanted Garden, you encounter a mischievous fairy holding the next clue:")
        print(f"Fairy: Hello, {name}! To move forward, answer my question:")
        print('Fairy: "The more you take, the more you leave behind. What am I?"')

        answer2 = input("Your answer: ")
        if answer2.lower() == "footsteps":
            print('Fairy: Impressive! You can now enter the Whispering Woods.\n')

            print("As you journey through the Whispering Woods, you hear mysterious voices in the wind.")
            print("A mystical tree challenges you with a riddle:")
            print('Mystical Tree: "I speak without a mouth and hear without ears. I have no body, but I come alive with the wind. What am I?"')

            answer3 = input("Your answer: ")
            if answer3.lower() == "echo":
                print("The mystical tree nods approvingly, allowing you to pass deeper into the forest.\n")

                print("You reach the Crystal Lake where a magical creature awaits with another riddle:")
                print('Magical Creature: "I fly without wings. I cry without eyes. Wherever I go, darkness follows me. What am I?"')

                answer4 = input("Your answer: ")
                if answer4.lower() == "cloud":
                    print('Magical Creature: Well done, brave adventurer! The Crystal of Destiny is near.\n')

                    print("At the heart of the enchanted forest, you find the Crystal of Destiny.")
                    print(f"Congratulations, {name}! You have successfully completed the quest and secured the legendary treasure.")
                else:
                    print("\nOops! Your journey ends here. Game over!")

            else:
                print("\nOops! Your journey ends here. Game over!")

        else:
            print("\nOops! Your journey ends here. Game over!")

    else:
        print('\nMystical Creature: Wrong answer! The enchanted gate remains closed. GAME OVER!\n')
